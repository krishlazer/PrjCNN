# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Dense, Dropout, LSTM, Conv2D, GRU, MaxPooling2D, Flatten, Softmax, Embedding
from tensorflow.keras.models import Sequential
import string
import re
from sklearn.preprocessing import MinMaxScaler
from collections import Counter

# %%
dfhp1 = pd.read_csv('E:/KrishM/PythonPrjs/PyDatasets/happydbex/megagonlabs-HappyDB-b9e529e/happydb/data/cleaned_hm.csv')

# %%
dfhp1
# Out:
#           hmid   wid reflection_period  \
# 0        27673  2053               24h
# 1        27674     2               24h
# 2        27675  1936               24h
# 3        27676   206               24h
# 4        27677  6227               24h
# ...        ...   ...               ...
# 100530  128762   112               24h
# 100531  128763   714               24h
# 100532  128764  3934               24h
# 100533  128765  1629               24h
# 100534  128766   141               24h
#
#                                               original_hm  \
# 0       I went on a successful date with someone I fel...
# 1       I was happy when my son got 90% marks in his e...
# 2            I went to the gym this morning and did yoga.
# 3       We had a serious talk with some friends of our...
# 4       I went with grandchildren to butterfly display...
# ...                                                   ...
# 100530  My husband announced he is getting a decent bo...
# ...

# %%
dfhp1 = dfhp1.iloc[:, [4, 8]]

# %%
dfhp1
# Out:
#                                                cleaned_hm predicted_category
# 0       I went on a successful date with someone I fel...          affection
# 1       I was happy when my son got 90% marks in his e...          affection
# 2            I went to the gym this morning and did yoga.           exercise
# 3       We had a serious talk with some friends of our...            bonding
# 4       I went with grandchildren to butterfly display...          affection
# ...                                                   ...                ...
# 100530  My husband announced he is getting a decent bo...          affection
# 100531                       Had a can of Pepsi to drink.   enjoy_the_moment
# 100532            Cuddling with my girlfriend last night.          affection
# 100533  I had a great meeting yesterday at work with m...            bonding
# 100534                  I had a great workout last night.           exercise
#
# [100535 rows x 2 columns]

# %%
dfhp1['predicted_category'] = LabelEncoder().fit_transform(dfhp1['predicted_category'])
# Out:
# <ipython-input-6-87122ceaee0b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfhp1['predicted_category'] = LabelEncoder().fit_transform(dfhp1['predicted_category'])

# %%
dfhp1
# Out:
#                                                cleaned_hm  predicted_category
# 0       I went on a successful date with someone I fel...                   1
# 1       I was happy when my son got 90% marks in his e...                   1
# 2            I went to the gym this morning and did yoga.                   4
# 3       We had a serious talk with some friends of our...                   2
# 4       I went with grandchildren to butterfly display...                   1
# ...                                                   ...                 ...
# 100530  My husband announced he is getting a decent bo...                   1
# 100531                       Had a can of Pepsi to drink.                   3
# 100532            Cuddling with my girlfriend last night.                   1
# 100533  I had a great meeting yesterday at work with m...                   2
# 100534                  I had a great workout last night.                   4
#
# [100535 rows x 2 columns]

# %%
tkn1 = Tokenizer(oov_token='<OOV>', filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n')

# %%
tkn1.fit_on_texts(dfhp1['cleaned_hm'])

# %%
tkn1

# %%
wdix = tkn1.word_index

# %%
wdix
# Out:
# {'<OOV>': 1,
#  'i': 2,
#  'my': 3,
#  'a': 4,
#  'to': 5,
#  'and': 6,
#  'the': 7,
#  'was': 8,
#  'for': 9,
#  'in': 10,
#  'me': 11,
#  'of': 12,
#  'that': 13,
#  'with': 14,
#  'it': 15,
#  'happy': 16,
#  'on': 17,
#  'got': 18,
#  'had': 19,
#  'at': 20,
#  'made': 21,
#  'we': 22,
#  'when': 23,
#  'went': 24,
#  'is': 25,
#  'time': 26,
#  'very': 27,
#  'new': 28,
#  'from': 29,
#  'so': 30,
#  'out': 31,
#  'day': 32,
#  'work': 33,
#  'this': 34,
#  'an': 35,
#  'her': 36,
#  'have': 37,
#  'last': 38,
#  'some': 39,
#  'good': 40,
#  'friend': 41,
#  'up': 42,
#  'after': 43,
#  'she': 44,
#  'he': 45,
#  'really': 46,
#  'one': 47,
#  'able': 48,
#  'today': 49,
#  'all': 50,
#  'friends': 51,
#  'family': 52,
#  'first': 53,
#  'been': 54,
#  'our': 55,
#  'about': 56,
#  'as': 57,
#  'am': 58,
#  'home': 59,
#  'be': 60,
#  'get': 61,
#  'but': 62,
#  'found': 63,
#  'his': 64,
#  'which': 65,
#  'yesterday': 66,
#  'great': 67,
#  'not': 68,
#  'because': 69,
# ...

# %%
len(wdix)
# Out:
# 26361

# %%
sentences = tkn1.fit_on_texts(dfhp1['cleaned_hm'])

# %%
sentences

# %%
tkn1.fit_on_sequences(sentences)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-2b199d2b1cce> in <module>
# ----> 1 tkn1.fit_on_sequences(sentences)
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\keras_preprocessing\text.py in fit_on_sequences(self, sequences)
#     261                 A "sequence" is a list of integer word indices.
#     262         """
# --> 263         self.document_count += len(sequences)
#     264         for seq in sequences:
#     265             seq = set(seq)
#
# TypeError: object of type 'NoneType' has no len()
